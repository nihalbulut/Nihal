# %%
import pandas as pd

# %%
from pycaret.classification import *

# %%
df = pd.read_csv("16P.csv", encoding="ISO-8859-1")

# %%
df.head()
# Out:
#    Response Id  You regularly make new friends.  \
# 0            0                                0
# 1            1                                0
# 2            2                                0
# 3            3                                0
# 4            4                                0
#
#    You spend a lot of your free time exploring various random topics that pique your interest  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                 -1
# 4                                                  0
#
#    Seeing other people cry can easily make you feel like you want to cry too  \
# 0                                                  0
# 1                                                 -2
# 2                                                  2
# 3                                                  3
# ...

# %%
setup(df,target="Personality")
# Out:
# <style type="text/css">
# #T_7eefc_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7eefc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7eefc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7eefc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7eefc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7eefc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7eefc_row0_col1" class="data row0 col1" >6740</td>
#     </tr>
#     <tr>
#       <th id="T_7eefc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7eefc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7eefc_row1_col1" class="data row1 col1" >Personality</td>
#     </tr>
#     <tr>
#       <th id="T_7eefc_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
df.Personality.nunique()
# Out:
# 16

# %%
df["Personality"].unique()
# Out:
# array(['ENFP', 'ISFP', 'INFJ', 'ISTP', 'ENFJ', 'INTJ', 'ENTJ', 'ESFP',
#        'INFP', 'INTP', 'ISTJ', 'ENTP', 'ISFJ', 'ESTJ', 'ESTP', 'ESFJ'],
#       dtype=object)

# %%
df["Personality"]=df["Personality"].replace("ENFP",1)
df["Personality"]=df["Personality"].replace("ISFP",2)
df["Personality"]=df["Personality"].replace("INFJ",3)
df["Personality"]=df["Personality"].replace("ISTP",4)
df["Personality"]=df["Personality"].replace("ENFJ",5)
df["Personality"]=df["Personality"].replace("INTJ",6)
df["Personality"]=df["Personality"].replace("ENTJ",7)
df["Personality"]=df["Personality"].replace("ESFP",8)
df["Personality"]=df["Personality"].replace("INFP",9)
df["Personality"]=df["Personality"].replace("INTP",10)
df["Personality"]=df["Personality"].replace("ISTJ",11)
df["Personality"]=df["Personality"].replace("ENTP",12)
df["Personality"]=df["Personality"].replace("ISFJ",13)
df["Personality"]=df["Personality"].replace("ESTJ",14)
df["Personality"]=df["Personality"].replace("ESTP",15)
df["Personality"]=df["Personality"].replace("ESFJ",16)

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_2eeea th {
#   text-align: left;
# }
# ...

# %%
dt=create_model("dt",fold=10)
# Out:
# <style type="text/css">
# #T_c21cb_row10_col0, #T_c21cb_row10_col1, #T_c21cb_row10_col2, #T_c21cb_row10_col3, #T_c21cb_row10_col4, #T_c21cb_row10_col5, #T_c21cb_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c21cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c21cb_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_c21cb_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_c21cb_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_c21cb_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_c21cb_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_c21cb_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_c21cb_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
dt=create_model("dt")
# Out:
# <style type="text/css">
# #T_04b39_row10_col0, #T_04b39_row10_col1, #T_04b39_row10_col2, #T_04b39_row10_col3, #T_04b39_row10_col4, #T_04b39_row10_col5, #T_04b39_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_04b39">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04b39_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_04b39_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_04b39_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_04b39_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_04b39_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_04b39_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_04b39_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
from sklearn.model_selection import train_test_split

# %%
y=df["Personality"]

# %%
x=df.drop("Personality", axis=1)

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.20, random_state=42)

# %%
q=QuadraticDiscriminantAnalysis()

# %%
q.fit(x,y)
# Out:
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)

# %%
x=pd.get_dummies(x,drop_first=True)

# %%
from sklearn.metrics import roc_auc_score

# %%
tahmin=q.predict(x)

# %%
roc_auc_score(tahmin,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 roc_auc_score(tahmin,y)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py:560, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     553         raise ValueError(
#     554             "Partial AUC computation not available in "
#     555             "multiclass setting, 'max_fpr' must be"
#     556             " set to `None`, received `max_fpr={0}` "
#     557             "instead".format(max_fpr)
#     558         )
#     559     if multi_class == "raise":
# --> 560         raise ValueError("multi_class must be in ('ovo', 'ovr')")
#     561     return _multiclass_roc_auc_score(
#     562         y_true, y_score, labels, multi_class, average, sample_weight
#     563     )
#     564 elif y_type == "binary":
#
# ...
