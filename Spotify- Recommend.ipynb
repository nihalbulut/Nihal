# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# ...

# %%
df.tail()
# Out:
#         valence  year  acousticness  \
# 170648    0.608  2020       0.08460
# 170649    0.734  2020       0.20600
# 170650    0.637  2020       0.10100
# 170651    0.195  2020       0.00998
# 170652    0.642  2020       0.13200
#
#                                                   artists  danceability  \
# 170648  ['Anuel AA', 'Daddy Yankee', 'KAROL G', 'Ozuna...         0.786
# 170649                                       ['Ashnikko']         0.717
# 170650                                        ['MAMAMOO']         0.634
# 170651                                         ['Eminem']         0.671
# 170652                              ['KEVVO', 'J Balvin']         0.856
#
#         duration_ms  energy  explicit                      id  \
# 170648       301714   0.808         0  0KkIkfsLEJbrcIhYsCL7L5
# 170649       150654   0.753         0  0OStKKAuXlxA0fMH54Qs6E
# 170650       211280   0.858         0  4BZXVFYCb76Q0Klojq4piV
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170653 entries, 0 to 170652
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   valence           170653 non-null  float64
#  1   year              170653 non-null  int64
#  2   acousticness      170653 non-null  float64
#  3   artists           170653 non-null  object
#  4   danceability      170653 non-null  float64
#  5   duration_ms       170653 non-null  int64
#  6   energy            170653 non-null  float64
#  7   explicit          170653 non-null  int64
#  8   id                170653 non-null  object
#  9   instrumentalness  170653 non-null  float64
#  10  key               170653 non-null  int64
#  11  liveness          170653 non-null  float64
#  12  loudness          170653 non-null  float64
#  13  mode              170653 non-null  int64
#  14  name              170653 non-null  object
#  15  popularity        170653 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# valence             0
# year                0
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# dtype: int64

# %%
df.shape
# Out:
# (170653, 19)

# %%
df["mode"].nunique()
# Out:
# 2

# %%
grouped=df.groupby("name").agg({"popularity":[np.size,np.sum,np.mean]})

# %%
grouped.head()
# Out:
#                           popularity
#                                 size sum  mean
# name
# !Que Vida! - Mono Version          1  26  26.0
# "40"                               1  23  23.0
# "40" - Live                        1  39  39.0
# "40" - Remastered 2008             2  71  35.5
# "45"                               1  50  50.0

# %%
populer=grouped.sort_values(("popularity","mean"),ascending=False)

# %%
toplam=grouped["popularity"]["sum"].sum()

# %%
populer["percentage"]=populer["popularity","sum"].div(toplam)*100

# %%
populer.head()
# Out:
#                                 popularity             percentage
#                                       size  sum   mean
# name
# Dakiti                                   1  100  100.0   0.001864
# Mood (feat. iann dior)                   1   99   99.0   0.001846
# What You Know Bout Love                  1   96   96.0   0.001790
# WAP (feat. Megan Thee Stallion)          1   96   96.0   0.001790
# Blinding Lights                          1   96   96.0   0.001790

# %%
populer.sort_values(("percentage"),ascending=False)
# Out:
#                                popularity                  percentage
#                                      size   sum       mean
# name
# White Christmas                        73  1982  27.150685   0.036951
# Winter Wonderland                      63  1943  30.841270   0.036223
# Home                                   40  1913  47.825000   0.035664
# Summertime                             56  1672  29.857143   0.031171
# Stay                                   33  1625  49.242424   0.030295
# ...                                   ...   ...        ...        ...
# Ankhon Ne Kaha Dil Ne Suna              1     0   0.000000   0.000000
# Ankhon Men Lagi Raat                    1     0   0.000000   0.000000
# Часть 86.2 - Триумфальная арка          1     0   0.000000   0.000000
# Στα Γιάννενα στα Δέρβαινα               1     0   0.000000   0.000000
# Cielo Azul                              1     0   0.000000   0.000000
#
# [133638 rows x 4 columns]

# %%
df1=df[["id","name","popularity","release_date"]]

# %%
df1.head()
# Out:
#                        id                                               name  \
# 0  4BJqT0PrAfrxzMOxytFOIz  Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 1  7xPhfUan2yNtyFG0cUWkt8                            Clancy Lowered the Boom
# 2  1o6I8BglA6ylDMrIELygv1                                          Gati Bali
# 3  3ftBPsC5vPBKxYSee08FDH                                          Danny Boy
# 4  4d6HGyGT8e121BsdKmw9v6                        When Irish Eyes Are Smiling
#
#    popularity release_date
# 0           4         1921
# 1           5         1921
# 2           5         1921
# 3           3         1921
# 4           2         1921

# %%
import numpy as np

# %%
df1.shape
# Out:
# (170653, 4)

# %%
sliced_spotify=df1[:10000]

# %%
sliced_spotify.shape
# Out:
# (10000, 4)

# %%
musicratings=sliced_spotify.pivot_table(index=["id"],columns=["name"],values="popularity")

# %%
musicratings.head()
# Out:
# name                    "A" You're Adorable  "Jubel" - Overture, Op. 59  \
# id
# 004cCP7Csq7U0m67DDzEFs                  NaN                         NaN
# 006fbuXS6rRAWlUEaklCmt                  NaN                         NaN
# 007PHg6gge5dW1wnOEtucm                  NaN                         NaN
# 007cHgcM8RRS4IYQOaPQ6u                  NaN                         NaN
# 008X8kpgdmgWnoYB90s9Ap                  NaN                         NaN
#
# name                    ' Cello Song  'A vucchella  'Cause I Feel Lowdown  \
# id
# 004cCP7Csq7U0m67DDzEFs           NaN           NaN                    NaN
# 006fbuXS6rRAWlUEaklCmt           NaN           NaN                    NaN
# 007PHg6gge5dW1wnOEtucm           NaN           NaN                    NaN
# 007cHgcM8RRS4IYQOaPQ6u           NaN           NaN                    NaN
# 008X8kpgdmgWnoYB90s9Ap           NaN           NaN                    NaN
#
# name                    'Cross the Brazos at Waco  'Deed I Do  \
# id
# ...

# %%
white=musicratings["White Christmas"]

# %%
white
# Out:
# id
# 004cCP7Csq7U0m67DDzEFs   NaN
# 006fbuXS6rRAWlUEaklCmt   NaN
# 007PHg6gge5dW1wnOEtucm   NaN
# 007cHgcM8RRS4IYQOaPQ6u   NaN
# 008X8kpgdmgWnoYB90s9Ap   NaN
#                           ..
# 7zmVAVcT1oho7iWJGpApkE   NaN
# 7zo874QI1WRvHklBM9qjws   NaN
# 7zph0VMbYl7KoqReyowKiv   NaN
# 7zrxGPR1UVK2iSK793vLPl   NaN
# 7zxiwcqLQyWcLdThrsYklu   NaN
# Name: White Christmas, Length: 10000, dtype: float64

# %%
musicratings.corrwith(white).sort_values(ascending=False)
# Out:
# name
# White Christmas               1.0
# "A" You're Adorable           NaN
# "Jubel" - Overture, Op. 59    NaN
# ' Cello Song                  NaN
# 'A vucchella                  NaN
#                              ...
# 說不出的快活                        NaN
# 郎如春日風                         NaN
# 魂縈舊夢                          NaN
# 鳳凰于飛 - 二                      NaN
# 黃葉舞秋風                         NaN
# Length: 8664, dtype: float64
